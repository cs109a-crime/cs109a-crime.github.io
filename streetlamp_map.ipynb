# %%
import pandas as pd
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd
import numpy as np
from shapely.geometry import Point, Polygon

# %%
boston_map = gpd.read_file('Boston_Neighborhoods/Boston_Neighborhoods.shp')

# %%
fig,ax = plt.subplots(figsize=(15,15))
boston_map.plot(ax=ax,alpha=0.7,color='grey')
geo_df.plot(ax=ax,markersize=1)
plt.xlim(-71.1,-71.0)
plt.ylim(42.32,42.4)
plt.show()

# %%
streetlights_full = pd.read_csv('data/streetlight_locations.csv')
streetlights = streetlights_full.drop(['the_geom','TYPE','OBJECTID'],axis=1)

# %%
crs = {'init': 'epsg:4326'}

# %%
geometry = [Point(xy) for xy in zip(streetlights.Long,streetlights.Lat)]
df = pd.DataFrame(np.ones(len(streetlights)))

# %%
geo_df = gpd.GeoDataFrame(df,crs=crs,geometry=geometry)
geo_df.head()
# Out:
#      0                                  geometry
# 0  1.0      POINT (-71.0760443808 42.3531592506)
# 1  1.0      POINT (-71.0753817124 42.3533477681)
# 2  1.0      POINT (-71.0747748806 42.3535205207)
# 3  1.0  POINT (-71.0744037348 42.35355582010001)
# 4  1.0  POINT (-71.07362079550001 42.3538105642)
